# %% [markdown]
# <a href="https://colab.research.google.com/github/SonalShukla-projects/Bankruptcy_Prediction_Company_ML_Project/blob/main/notebooks/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path="/content/drive/MyDrive/ML_DATASETS/data.csv"
df=pd.read_csv(path)
df.head(5)

# %%
print("Dataset Shape:", df.shape)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.columns

# %%
X = df.drop("Bankrupt?", axis=1)
y = df["Bankrupt?"]

# %%
#Analyzed class imbalance in dataset
sns.countplot(x='Bankrupt?', data=df)
plt.title("Bankruptcy Distribution")
plt.show()

# %% [markdown]
# **Data Preprocessing**

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr())
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# **Data Preparation**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# **CREATE AND DOWNLOAD CLEANED DATASET**

# %%
clean_df = X_scaled.copy()

clean_df["Bankrupt?"] = y

# %%
clean_df.to_csv("clean_bankruptcy_data.csv", index=False)

from google.colab import files
files.download("clean_bankruptcy_data.csv")
